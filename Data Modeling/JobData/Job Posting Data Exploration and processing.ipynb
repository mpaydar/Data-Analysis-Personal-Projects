# %% [markdown]
# # About the dataset

# %% [markdown]
# The data is about the 19,000 job posting which was posted on an Online Job post board . The dataset covers job posting as early as 2004 to 2015. In this analysis, we want to know which job sector is the most demanding and which branch of the sector would be the top job in the market. In the dataset, there are 24 features as follow:
#
# 1. Jobpost – The original job post
# 2. date – Date it was posted in the group
# 3. Title – Job title
# 4. Company - employer
# 5. AnnouncementCode – Announcement code (some internal code, is usually missing)
# 6. Term – Full-Time, Part-time, etc
# 7. Eligibility -- Eligibility of the candidates
# 8. Audience --- Who can apply?
# 9. StartDate – Start date of work
# 10. Duration - Duration of the employment
# 11. Location – Employment location
# 12. JobDescription – Job Description
# 13. JobRequirment - Job requirements
# 14. RequiredQual -Required Qualification
# 15. Salary - Salary
# 16. ApplicationP – Application Procedure
# 17. OpeningDate – Opening date of the job announcement
# 18. Deadline – Deadline for the job announcement
# 19. Notes - Additional Notes
# 20. AboutC - About the company
# 21. Attach - Attachments
# 22. Year - Year of the announcement (derived from the field date)
# 23. Month - Month of the announcement (derived from the field date)
# 24. IT – TRUE if the job is an IT job. This variable is created by a simple search of IT job titles within column “Title”

# %%
import pandas as pd
import missingno as msno
df=pd.read_csv('https://raw.githubusercontent.com/mpaydar/Data-Analysis-Personal-Projects/main/JobData/data%20job%20posts.csv')
df_copy=df
df.columns
# Out:
# Index(['jobpost', 'date', 'Title', 'Company', 'AnnouncementCode', 'Term',
#        'Eligibility', 'Audience', 'StartDate', 'Duration', 'Location',
#        'JobDescription', 'JobRequirment', 'RequiredQual', 'Salary',
#        'ApplicationP', 'OpeningDate', 'Deadline', 'Notes', 'AboutC', 'Attach',
#        'Year', 'Month', 'IT'],
#       dtype='object')

# %% [markdown]
# ## Checking number of NA values in each column

# %%
a=df.isnull().sum()
b= df.isna().sum()
pd.DataFrame(b)
# Out:
#                       0
# jobpost               0
# date                  0
# Title                28
# Company               7
# AnnouncementCode  17793
# Term              11325
# Eligibility       14071
# Audience          18361
# StartDate          9326
# Duration           8203
# Location             32
# JobDescription     3892
# JobRequirment      2522
# RequiredQual        484
# Salary             9379
# ApplicationP         60
# OpeningDate         706
# Deadline             65
# Notes             16790
# AboutC             6531
# Attach            17442
# Year                  0
# Month                 0
# IT                    0

# %% [markdown]
# ## Dropping Out of Context Data

# %% [markdown]
# The table reveals a significant number of NA values in certain attributes of our dataset. Upon closer inspection, it becomes apparent that these missing values are irrelevant and inconsequential for our specific data exploration purposes. Hence, we can safely disregard these out-of-context values and proceed with our analysis. We would drop the following attributes from the dataset:
# 1. AnnouncmentCode
# 2. Term
# 3. Eligibility
# 4. Audience
# 5. StartDate
# 6. Duration
# 7. Notes
# 8. Attach
# 9. JobDescription
# 10. JobRequirement
# 11. Salary
# 12. AboutC
# 13. ApplicationP

# %%
df.dropna(subset=['Notes'] ,axis=0,inplace=True)
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
toBeReomve=["JobRequirment","Salary","AboutC","AnnouncementCode","Term","Eligibility","Audience","StartDate","Duration","Notes","Attach","JobDescription","ApplicationP"]
for i in toBeReomve:
    df.drop(i, axis=1, inplace=True)
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
bins=np.linspace(min(df["price"]),max())
